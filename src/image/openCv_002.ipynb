# %%
# display images otside lupyter lab

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import cv2

img = cv2.imread('../output/00-puppy.jpg')
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
cv2.imshow('Puppy', img_rgb)
cv2.waitKey()

# %%
print(1)
# Out:
# 1
