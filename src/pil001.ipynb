# %%
import numpy as np

# %% [raw]
# import matplotlib.pyplot as plt

# %%
from PIL import Image

# %%
pic = Image.open('../output/scatter_plot.png')

# %%
pic
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=640x480>

# %%
type(pic)
# Out:
# PIL.PngImagePlugin.PngImageFile

# %%
pic_arr=np.asarray(pic)

# %%
pic_arr
# Out:
# array([[[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
# ...

# %%
type(pic_arr)
# Out:
# numpy.ndarray

# %%
pic_arr.shape
# Out:
# (480, 640, 4)

# %%
plt.imshow(pic_arr)

# %%
pic_red = pic_arr.copy()

# %%
plt.imshow(pic_red)

# %%
# R G B A
# RED CHANAL VALUES 0-255
plt.imshow(pic_red[:,:,0],cmap='gray')

# %%
# R G B A
# GREEN CHANAL VALUES 0-255
plt.imshow(pic_red[:,:,1],cmap='gray')

# %%
# R G B A
# BLUE CHANAL VALUES 0-255
plt.imshow(pic_red[:,:,2],cmap='gray')

# %%
# R G B A
# ALPHA CHANAL VALUES 0-255
plt.imshow(pic_red[:,:,3],cmap='gray')

# %%
# get rid of green chana
pic_red[:,:,1]=0

# %%
# get rid of blue chana
pic_red[:,:,2]=0

# %%
# get rid of red chana
pic_red[:,:,0]=0

# %%
plt.imshow(pic_red)

# %%
pic_red.shape
# Out:
# (480, 640, 4)

# %%
pic_red[:,:,0].shape
# Out:
# (480, 640)

# %%
plt.imshow(pic)

# %%
b = np.ones(shape=(5,2))

# %%
b*10
# Out:
# array([[10., 10.],
#        [10., 10.],
#        [10., 10.],
#        [10., 10.],
#        [10., 10.]])

# %%
b/2
# Out:
# array([[0.5, 0.5],
#        [0.5, 0.5],
#        [0.5, 0.5],
#        [0.5, 0.5],
#        [0.5, 0.5]])
