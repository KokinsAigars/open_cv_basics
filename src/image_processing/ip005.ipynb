# %% [markdown]
# ### Adding Noise
#
# Let's see a more useful case of Median Blurring by adding some random noise to an image.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
def load_img():
    img = cv2.imread('/app/output/00-puppy.jpg')
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    return img

# %%
def display_img(img):
    fig = plt.figure(figsize=(12,10))
    ax = fig.add_subplot(111)
    ax.imshow(img)

# %%
img = load_img()
display_img(img)

# %%
img.max()
# Out:
# np.uint8(216)

# %%
img.min()
# Out:
# np.uint8(0)

# %%
img.mean()
# Out:
# np.float64(50.96364220907298)

# %%
img.shape
# Out:
# (1300, 1950, 3)

# %%
display_img(img)

# %%
noise_img = cv2.imread('/app/output/00-puppy.jpg')
noise_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
display_img(noise_img)

# %%
median = cv2.medianBlur(noise_img,55)
display_img(median)
