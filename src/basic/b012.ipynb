# %% [markdown]
# ## Edge Detection & Image Gradients

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
img = cv2.imread('/app/output/opencv.png')
image = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
# Extract Sobel Edges
sobel_x = cv2.Sobel(image, cv2.CV_64F, 0, 1, ksize=5)
sobel_y = cv2.Sobel(image, cv2.CV_64F, 1, 0, ksize=5)

# %%
plt.imshow(sobel_x)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-12240.0..12240.0].

# %%
plt.imshow(sobel_y)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-12240.0..12240.0].

# %%
sobel_OR = cv2.bitwise_or(sobel_x, sobel_y)
plt.imshow(sobel_OR)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-131064.0..131040.0].

# %%
laplacian = cv2.Laplacian(image, cv2.CV_64F)
plt.imshow(laplacian)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-568.0..579.0].

# %%
img_input = cv2.imread('/app/output/input.jpg',0)
canny = cv2.Canny(img_input, 50, 120)
plt.imshow(canny, cmap='gray')
