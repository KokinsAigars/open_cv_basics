# %%
### BASIC

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
img = cv2.imread('/app/output/some_img.png')
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
# plt.imshow(img_rgb)

# %%
# plt.imshow(img_gray,cmap='gray')

# %%
# plt.imshow(img_gray,cmap='gray_r')

# %%
img_rgb.shape
# Out:
# (3072, 3072, 3)

# %%
B, G, R = img_rgb[1500,1500]

# %%
print(B, G, R)
# Out:
# 177 170 159

# %%
B, G, R = cv2.split(img_rgb)

# %%
print(B.shape)
# Out:
# (3072, 3072)

# %%
print(G.shape)
# Out:
# (3072, 3072)

# %%
print(R.shape)
# Out:
# (3072, 3072)

# %%
plt.imshow(R)

# %%
plt.imshow(G)

# %%
plt.imshow(B)

# %%
merged = cv2.merge([B+10, G, R])

# %%
plt.imshow(merged)

# %%
zeros = np.zeros(merged.shape[:2], dtype = 'uint8')

# %%
mergedR = cv2.merge([zeros, zeros, R])

# %%
# plt.imshow(mergedR)

# %%
mergedG = cv2.merge([zeros, G, zeros])

# %%
# plt.imshow(mergedG)

# %%
mergedB = cv2.merge([B, zeros, zeros])
