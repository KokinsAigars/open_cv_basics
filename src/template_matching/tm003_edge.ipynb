# %% [markdown]
# # Canny Edge Detection
# https://en.wikipedia.org/wiki/Canny_edge_detector

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread('/app/output/sammy_face.jpg')
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img)

# %%
edges = cv2.Canny(image=img, threshold1=127, threshold2=127)
plt.imshow(edges)

# %% [markdown]
# # adding bloor before canny edge detection

# %%
blurred_img = cv2.GaussianBlur(img,(5,5),10)
plt.imshow(blurred_img)

# %%
edges = cv2.Canny(image=blurred_img, threshold1=127, threshold2=127)
plt.imshow(edges)

# %% [markdown]
# ## Choosing Thresholds
#
# https://stackoverflow.com/questions/25125670/best-value-for-threshold-in-canny

# %%
# Calculate the median pixel value
med_val = np.median(edges)

# %%
# Lower bound is either 0 or 70% of the median value, whicever is higher
lower = int(max(0, 0.7* med_val))

# %%
lower
# Out:
# 0

# %%
# Upper bound is either 255 or 30% above the median value, whichever is lower
upper = int(min(255,1.3 * med_val))

# %%
edges = cv2.Canny(image=edges, threshold1=lower , threshold2=upper)

# %%
plt.imshow(edges)
