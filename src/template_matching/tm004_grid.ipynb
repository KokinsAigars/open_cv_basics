# %% [markdown]
# # Grid Detection

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
flat_chess = cv2.imread('/app/output/flat_chessboard.png',0)
flat_chess = cv2.cvtColor(flat_chess, cv2.COLOR_BGR2RGB)
plt.imshow(flat_chess)

# %%
plt.imshow(flat_chess,cmap='gray')

# %%
found, corners = cv2.findChessboardCorners(flat_chess,(7,7))

# %%
if found:
    print('OpenCV was able to find the corners')
else:
    print("OpenCV did not find corners. Double check your patternSize.")
# Out:
# OpenCV was able to find the corners

# %%
corners.shape
# Out:
# (49, 1, 2)

# %%
flat_chess_copy = flat_chess.copy()
cv2.drawChessboardCorners(flat_chess_copy, (7, 7), corners, found)
# Out:
# array([[[215, 215, 215],
#         [215, 215, 215],
#         [215, 215, 215],
#         ...,
#         [152, 152, 152],
#         [152, 152, 152],
#         [152, 152, 152]],
#
#        [[215, 215, 215],
#         [215, 215, 215],
#         [215, 215, 215],
#         ...,
#         [152, 152, 152],
#         [152, 152, 152],
#         [152, 152, 152]],
#
#        [[215, 215, 215],
#         [215, 215, 215],
#         [215, 215, 215],
#         ...,
#         [152, 152, 152],
#         [152, 152, 152],
#         [152, 152, 152]],
#
#        ...,
#
#        [[152, 152, 152],
#         [152, 152, 152],
#         [152, 152, 152],
#         ...,
#         [215, 215, 215],
#         [215, 215, 215],
#         [215, 215, 215]],
#
#        [[152, 152, 152],
#         [152, 152, 152],
#         [152, 152, 152],
#         ...,
#         [215, 215, 215],
#         [215, 215, 215],
#         [215, 215, 215]],
#
#        [[152, 152, 152],
#         [152, 152, 152],
#         [152, 152, 152],
#         ...,
#         [215, 215, 215],
#         [215, 215, 215],
#         [215, 215, 215]]], shape=(352, 352, 3), dtype=uint8)

# %%
plt.imshow(flat_chess_copy)

# %%
dots = cv2.imread('/app/output/dot_grid.png')

# %%
plt.imshow(dots)

# %%
found, corners = cv2.findCirclesGrid(dots, (10,10), cv2.CALIB_CB_SYMMETRIC_GRID)

# %%
dbg_image_circles = dots.copy()
cv2.drawChessboardCorners(dbg_image_circles, (10, 10), corners, found)
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]]], shape=(600, 600, 3), dtype=uint8)

# %%
plt.imshow(dbg_image_circles)
